# %% [markdown]
# <a href="https://colab.research.google.com/github/atulkrs/atulkrs/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean


x = np.array([0,3,2,1,5,5,4,3,0,4])
y = np.array([2,8,7,3,13,12,9,9,3,10])

# %%
plt.scatter(x, y)

plt.show()

# %%
a, b = np.polyfit(x, y, 1)


plt.scatter(x, y, color='purple')


plt.plot(x, a*x+b, color='steelblue', linestyle='--', linewidth=2)

plt.text(1, 17, 'y = ' + '{:.2f}'.format(b) + ' + {:.2f}'.format(a) + 'x', size=14)
# Out:
# Text(1, 17, 'y = 2.23 + 1.99x')

# %%
a,b = np.polyfit(x,y, 1)

plt.scatter(x, y)
plt.plot(x, a*x+b)

# %%
xs = np.array([0,3,2,1,5,5,4,3,0,4], dtype=np.float64)
ys = np.array([2,8,7,3,13,12,9,9,3,10], dtype=np.float64)

def best_fit_slope(xs,ys):
  m= (((mean(xs)*mean(ys))-mean(xs*ys))/((mean(xs)**2) -mean(xs**2)))
  return m

m = best_fit_slope(xs, ys)
print(m)
# Out:
# 1.987538940809969

# %% [markdown]
# The y-intercept is the point where the graph of a line crosses the y-axis. In the coordinate plane shown, the y-intercept is 4 because the graph passes through 4 on the y-axis.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# r = 0 means there is no correlation. r = 1 means there is perfect positive correlation. r = -1 means there is a perfect negative correlation.
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# When n = 2 and r = 1, are the data insignificant if n=2 then it will give us undefined if r will be greater then one it will give us imaginery value

# %%
from scipy import stats
slope, intercept, r,p, er = stats.linregress(x,y)

# %%
a = [x for x in range(1,100)]
b = [x for x in range(1,100)]
b = sorted(b, reverse=True)

# %%
def fun(x):
  return slope * x + intercept

model = list(map(fun,a))

plt.plot(a,model)
plt.show()

# %%
slope, intercept, r,p, er = stats.linregress(a,b)
def fun(x):
  return slope * x + intercept

model = list(map(fun,a))

plt.scatter(a,b)
plt.plot(b,model)
plt.show()
r
# Out:
# -1.0
